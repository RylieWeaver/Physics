# %% [markdown]
# <a href="https://colab.research.google.com/github/RylieWeaver9/Physics/blob/main/Electronics%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 5**
#
# *   Rylie Weaver with lab partner Anthony Razo

# %% [markdown]
# # **1-A**

# %% [markdown]
# ##**Procedure**
#
# **A.** Collect the needed supplies.
#
# **B.** Connect and plug in the circuit.
#
# **C.** Use the oscillooscope to measure the needed values. This means using autorange, volts/div, and secs/div to zoom in and center the graph, then using cursors and pk -> pk to do the actual measurement.

# %% [markdown]
# **1.** Circuit Constructed
#
# **2.**
#
# $Input = 21.6V$
#
# $Output = 10.3V$
#
# **Question:** (input/2) - (output) = 0.5V, which is very close to the expected 0.6V

# %% [markdown]
# # **1-B**

# %% [markdown]
# ##**Procedure**
#
# **A.** Collect the needed supplies.
#
# **B.** Connect and plug in the circuit.
#
# **C.** Use the oscilloscope to measure the needed values. This means using autorange, volts/div, and secs/div to zoom in and center the graph, then using cursors and pk -> pk to do the actual measurement.

# %% [markdown]
# **1.** Circuit constructed.
#
# **2.** Done
#
# **3.** Done
#
# **4.**
#
# $Input = 21.6V$
#
# **5.**
#
# $Output = 9.6V$
#
# **Question:** The output is not the exact same as an ideal full-wave rectifier. In between the waves, there is a flat spot which is not exactly the perfect absolute value.
#
# **6.**
#
# $Input = 21.6V$
#
# $Output = 9.6V$
#
# **Question:** The W02G and the bridge that we built are exactly the same in my measurements!

# %% [markdown]
# # **2**

# %% [markdown]
# ##**Procedure**
#
# **A.** Collect the needed supplies.
#
# **B.** Connect and plug in the circuit.
#
# **C.** Use the oscillooscope to measure the needed values. This means using autorange, volts/div, and secs/div to zoom in and center the graph, then using cursors and pk -> pk to do the actual measurement.

# %% [markdown]
# **1.** Circuit constructed.
#
# **2/3/4/5/6**
#
# **10nf:**
#
# $Min: 2.6V$
#
# $Max: 10.2V$
#
# $PK -> PK: 7.6V$
#
# $V(dc) = 6.4V$
#
# $V(rms) = 2.19V$
#
# $\gamma = 0.34$
#
# **100nf:**
#
# $Min: 8.52V$
#
# $Max: 10.0V$
#
# $PK -> PK: 1.48V$
#
# $V(dc) = 9.26V$
#
# $V(rms) = 0.43V$
#
# $\gamma = 0.05$
#
# **1000nf:**
#
# $Min: 9.32V$
#
# $Max: 9.5V$
#
# $PK -> PK: 0.18V$
#
# $V(dc) = 9.41V$
#
# $V(rms) = 0.05V$
#
# $\gamma = 0.019$
#
# **Question:**
#
# The ripple factors are very close to the theoretical values.
#
# **7.**
#
# Circuit Sketched in LTSpice (image below)
#
# **8.**
#
# $Min: 8.08V$
#
# $Max: 8.64$
#
# $PK -> PK: 0.56V$
#
# $V(dc) = 8.36V$
#
# $V(rms) = 0.162V$
#
# $\gamma = 0.019$

# %%
from google.colab import drive
drive.mount('/content/drive')
from IPython.display import Image
Image('/content/drive/My Drive/Colab Notebooks/Electronics Lab 5 Circuit Sketch (1).PNG')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **3-A**

# %% [markdown]
# ##**Procedure**
#
# **A.** Collect the needed supplies.
#
# **B.** Connect and plug in the circuit.
#
# **C.** Use the oscilloscope to measure the needed values. This means using autorange, volts/div, and secs/div to zoom in and center the graph, then using cursors and pk -> pk to do the actual measurement.

# %% [markdown]
# **1.** Done
#
# **2.** Circuit constructed.
#
# **Question:** There is no voltage drop across LM7805 so there is no ripple.
