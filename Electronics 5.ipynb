# %% [markdown]
# <a href="https://colab.research.google.com/github/RylieWeaver9/Physics/blob/main/Electronics%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 6**
#
# *   Rylie Weaver with lab partner Chris Allen

# %% [markdown]
# # **1-A**

# %% [markdown]
# **1.** Done
#
# **2.** Done
#
# **3.** Done
#
# **4.**
#
# Diode $\Delta V = 0.547 V$
#
# **5.**
#
# BC $\Delta V = 0.638V$
#
# BE $\Delta V = 0.659 V$
#
# **6.** Done
#
# **7.** Done
#
# **8.** Done

# %% [markdown]
# # **1-B**

# %%
from google.colab import files
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e7c916d-93e5-4609-bf70-b37447bb9ee0" name="files[]" multiple disabled />
#      <output id="result-2e7c916d-93e5-4609-bf70-b37447bb9ee0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
Image('Lab 6 #1.PNG', width = 400)

# %% [markdown]
# **Resistor Measurements**
#
# Nominal ---> Real
#
# $1k\Omega$ ---> $1k\Omega$
#
# $1k\Omega$ ---> $1001\Omega$

# %% [markdown]
# **1.** Done
#
# **2.** Decade Resistance Box Resistance = $D_R$
#
# $D_R = 0\Omega$
#
# $I_c = 14.65mA$
#
# $I_b = 4.15mA$
#
# $\beta = 3.53$
#
# **3/4.**
#
# $D_R = 10\Omega$
#
# *   $I_c = 14.65mA$
#
# *   $I_b = 4.11mA$
#
# *   $\beta = 3.56$
#
# $D_R = 30\Omega$
#
# *   $I_c = 14.62mA$
#
# *   $I_b = 4.03mA$
#
# *   $\beta = 3.63$
#
# $D_R = 50\Omega$
#
# *   $I_c = 14.63mA$
#
# *   $I_b = 3.95mA$
#
# *   $\beta = 3.70$
#
# $D_R = 100\Omega$
#
# *   $I_c = 14.65mA$
#
# *   $I_b = 3.77mA$
#
# *   $\beta = 3.89$
#
# $D_R = 300\Omega$
#
# *   $I_c = 14.62A$
#
# *   $I_b = 3.19mA$
#
# *   $\beta = 4.58$
#
# $D_R = 500\Omega$
#
# *   $I_c = 14.61mA$
#
# *   $I_b = 2.77mA$
#
# *   $\beta = 5.27$
#
# $D_R = 1k\Omega$
#
# *   $I_c = 14.62mA$
#
# *   $I_b = 2.08mA$
#
# *   $\beta = 7.03$
#
# $D_R = 3k\Omega$
#
# *   $I_c = 14.59mA$
#
# *   $I_b = 1.04mA$
#
# *   $\beta = 14.03$
#
# $D_R = 5k\Omega$
#
# *   $I_c = 14.58mA$
#
# *   $I_b = 0.69mA$
#
# *   $\beta = 21.13$
#
# $D_R = 10k\Omega$
#
# *   $I_c = 14.55mA$
#
# *   $I_b = 0.37mA$
#
# *   $\beta = 39.32$
#
# $D_R = 30k\Omega$
#
# *   $I_c = 14.49mA$
#
# *   $I_b = 0.13mA$
#
# *   $\beta = 111.46$
#
# $D_R = 50k\Omega$
#
# *   $I_c = 14.07mA$
#
# *   $I_b = 82.3\mu A$
#
# *   $\beta = 170.96$
#
# $D_R = 100k\Omega$
#
# *   $I_c = 8.40mA$
#
# *   $I_b = 42\mu A$
#
# *   $\beta = 200$
#
# $D_R = 300k\Omega$
#
# *   $I_c = 2.88mA$
#
# *   $I_b = 14.2\mu A$
#
# *   $\beta = 202.82$
#
# $D_R = 500k\Omega$
#
# *   $I_c = 1.68mA$
#
# *   $I_b = 8.5\mu A$
#
# *   $\beta = 197.65$
#
# **5.** Plotted Below
#
# **Question:** Other groups had different values for the range when the gain is approximately constant, so it's a bad idea to design a circuit that depends *exactly* on the value of the transistor's current gain.

# %%
import matplotlib.pyplot as plt
 
x  = [0,10,30,50,100,300,500,1000,3000,5000,10000,30000,50000,100000,300000,500000]
y = [3.53,3.56,3.63,3.70,3.89,4.58,5.27,7.03,14.03,21.13,39.32,111.46,170.96,200,202.82,197.65]

plt.plot(x,y, marker = "o")

plt.xlabel("Decade Box Resistance(ohms)")
plt.ylabel("Current Gain")
plt.title("Current Gain vs. Resistance")

plt.show()

# %% [markdown]
# # **2.**

# %%
from google.colab import files
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da3397b2-fca2-4355-8c72-117cfab75322" name="files[]" multiple disabled />
#      <output id="result-da3397b2-fca2-4355-8c72-117cfab75322">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lab 6 #2.PNG to Lab 6 #2 (1).PNG

# %%
Image('Lab 6 #2.PNG', width = 400)

# %% [markdown]
# **Resistor Measurements**
#
# Nominal ---> Real
#
# $470\Omega$ ---> $471\Omega$
#
# $1k\Omega$ ---> $1k\Omega$

# %% [markdown]
# **1.** Done
#
# **2.** Decade Resistance Box Resistance = $D_R$
#
# from 1 ohm to 1000 pretty much the exact same, plot below
#
# $D_R = 1\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 3\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 10\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 30\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 50\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 100\Omega$
#
# *   $I_c = 4.27mA$
#
# *   $I_b = 20.9\mu A$
#
# $D_R = 1000\Omega$
#
# *   $I_c = 2.25mA$
#
# *   $I_b = 21.6\mu A$
#
# **Question:**
#
# By using the following formulas:
#
# $5V = I_eR_e + V(Be)$
#
# $15V = I_eR_e + I_cD_r$
#
# Then subtracting the top from the bottom:
#
# $10V = I_cD_r - V(Be)$
#
# We can simplify to:
#
# $I_c = (10V-V(Be))/D_r$
#
# By this formula, our actual values are nowhere close to our theoretical values. I suspect that my formula is wrong in some way.
#
# **Question:** Stops working normally at about $2500 \Omega$
#
# **Question:** A load resistance of $2740 \Omega$ makes the current drop by about 10%.

# %%
import matplotlib.pyplot as plt
 
x  = [0,0.477,1,1.477,1.699,2,3]
y = [20.9,20.9,20.9,20.9,20.9,20.9,21.6]
z = [4.27,4.27,4.27,4.27,4.27,2.25]
plt.plot(x, y, z, marker = "o")
plt.xscale('log')

plt.xlabel("log resistance(ohms)")
plt.ylabel("Current(microamps)")
plt.title("Current vs. Resistance")

plt.show()

# %% [markdown]
# # **3.**

# %%
from google.colab import files
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dca29b56-b54d-406a-910d-57d446eab1f0" name="files[]" multiple disabled />
#      <output id="result-dca29b56-b54d-406a-910d-57d446eab1f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lab 6 #3.PNG to Lab 6 #3.PNG

# %%
Image('Lab 6 #3.PNG', width = 400)

# %% [markdown]
# **A.** Done
#
# **B.** Done
#
# **Question:** The output has flat parts and smaller peaks, this is what we expect.
#
# **C.** Bth the input and output signals have a Pk ---> Pk value of 5V and a period of 1ms
