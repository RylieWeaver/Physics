# %% [markdown]
# <a href="https://colab.research.google.com/github/RylieWeaver9/Physics/blob/main/Electronics%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 8**
#
# *   Rylie Weaver / Kurt Schreiber

# %%
from google.colab import files
from IPython.display import Image

# %% [markdown]
# # **7-1 Op-Amp RC Relaxation Oscillator**

# %% [markdown]
# **Measurements**
#
# Nominal ---> Real
#
# Resistor 1: $690k\Omega$ ---> $690.263\Omega$
#
# Resistor 2: $10k\Omega$ ---> $9974\Omega$
#
# Resistor 3: $10k\Omega$ ---> $9811\Omega$
#
# Capacitor 1: $1nF$ ---> $0.915nF$

# %% [markdown]
# **A.** Done
#
# **B.** Done
#
# **C.** Done
#
# **D.** Done (Image Below)
#
# **E.** The period of the circuit is 0.27 milliseconds, meaning the frequency is 3.70 kHz, which matches our expected frequency.
#
# **F.** Done
#
# **G.** Done
#
# **H.** Done
#
# **I.**
#
# Inputs:
#
#  - Neg. Input: $13.4V$ (sawtooth graph)
#  - Pos. Input: $-13.4V$ (boxy graph)
#
# Output: $27.4V$
#
# **J.**
#
# Measured Frequency: $697Hz$
#
# **Question:**
#
# The expected frequency was $1000Hz$, which is very different from our measured $697Hz$.
#
# **Rylie Reflection:**
#
# Starting off, making the circuit in LTSpice was pretty easy, expecially with the image provided. After that, it was a difficult to use the OpAmp in a real life circuit, but once realizing how to read it's image we were able to do that too (along with other group's and Martin's help as well). We were able to understand everything in this section, but one question I have is why the opAmp symbol looks like that in LTSpice when it's a rectangle in real life.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1d0bed6-556c-4421-b1a6-c06dafec9349" name="files[]" multiple disabled />
#      <output id="result-e1d0bed6-556c-4421-b1a6-c06dafec9349">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Electronics Lab 8 Part 1.PNG to Electronics Lab 8 Part 1.PNG

# %%
Image('Electronics Lab 8 Part 1.PNG', width=700)

# %% [markdown]
# # **7-2 555 A-stable Oscillator**

# %% [markdown]
# **Measurements**
#
# Nominal ---> Real
#
# Resistor A: $10k\Omega$ ---> $\Omega$
#
# Resistor B: $2.2k\Omega$ ---> $\Omega$
#
# Resistor L: $10k\Omega$ ---> $\Omega$
#
# Capacitor 1: $0.1uF$ ---> $$
#
# Capacitor 2: $0.1uF$ ---> $$

# %% [markdown]
# **A.** Done
#
# **B.** Done (Image Below)
#
# **C.** Done
#
# **D.** Done, the frequency is $1000Hz$, perfect!
#
# **E.** Done
#
# **F.** Done
#
# **G.** Done
#
# **H.**
#
# Across Capacitor: $3.8V$
#
# Output: $0V and 15V$ square graph
#
# **I.**
#
# Frequency: $1034Hz$
#
# Duty Cycle: $71$% (within MOE)
#
# **J.**
#
# Pin 5 = $10V$
#
# **Question:** The frequency and data cycle are very close compared to the expected value.
#
# **Question:** When operated, this circuit fills up the capacitor until it reaches the threshold of 10 Volts, then discharges the capacitor, and repeats.
#
# **K.** Done
#
# **Question:** The frequency and duty cycle change a lot because with the diode the capacitor can't discharge.
#
# **L.** Done
#
# **Question:**
#
# $15V$ = $347Hz$
#
# $12.5V$ = $619Hz$
#
# $10V$ = $1022kHz$
#
# $8V$ = $1.234khz$
#
# $6V$ = $1.694kHz$
#
# $4V$ = $1.945kHz$
#
# **Rylie Reflection:**
#
# Again, the LTSpice was fairly easy but knowing how the a-stable oscillator works took a little while. Again, I understand everything that's happened so I have no questions about the section.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b1fe27f-4658-4cef-b067-911cdb7718fa" name="files[]" multiple disabled />
#      <output id="result-7b1fe27f-4658-4cef-b067-911cdb7718fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Electronics Lab 8 Part 2.PNG to Electronics Lab 8 Part 2.PNG

# %%
Image('Electronics Lab 8 Part 2.PNG', width=700)
