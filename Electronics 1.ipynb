# %% [markdown]
# <a href="https://colab.research.google.com/github/RylieWeaver9/Physics/blob/main/Electronics%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 1**
#  - Rylie Weaver

# %% [markdown]
# ### **LTSpice**

# %% [markdown]
# **Procedure:**
#
#
# 1.   Start up LTSpice.
# 2.   Make the circuit with resistors and their resistances, a battery and its voltage, wires, and a ground.
# 3.   Run the program.
# 4.   Label the 5 voltages and their locations in the wire.
# 5.   Calculate the voltage labels by hand to check them
# 6.   Screenshot the image of the circuit
# 7.   Insert the image here

# %% [markdown]
# **Equations**
#
#
# *   $V - I_1 R_1 - I_2 R_2 = 0$
# *   $R_p = R_1 R_2 / (R_1 + R_2)$

# %% [markdown]
# **Image**

# %%
from google.colab import drive
drive.mount('/content/drive')
from IPython.display import Image
# Out:
# Mounted at /content/drive

# %%
Image('/content/drive/My Drive/Colab Notebooks/lab1.PNG')

# %% [markdown]
# **Data**

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.array([0,1,2,3])
V = np.array([0,.6,.88,.93])
I = np.array([1.9,.75,.25,.1])

plt.xlabel('Time (seconds)')
plt.ylabel('Voltage (volts) / Current (amps)')
plt.scatter(t,V, c='r')
plt.plot(t,V)
plt.scatter(t,I, c='g')
plt.plot(t,I)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observations**
#
#
# 1.   My calculations by hand match those of the computer.
# 2.   The wire, resistors, and battery work as I would expect.

# %% [markdown]
# ### **Oscilloscope**

# %% [markdown]
# **Procedure**
#
#
# 1.   Plug in and turn on the Oscilloscope and Function Generator.
# 2.   Connect the function generator and the oscilloscope.
# 3.   Mess around with them until a wave comes on the screen.
# 4.   Connect the oscilloscope to the computer.
# 5.   Run openchoice on the computer.
# 6.   Screenshot the image of the wave.
# 7.   Insert it here.

# %% [markdown]
# **Image**

# %%
Image('/content/drive/My Drive/Colab Notebooks/Oscilloscope.PNG')

# %% [markdown]
# ### **Breadboard**

# %% [markdown]
# **Procedure**
#
#
# 1.   Connect the Ammeter to the Breadboard
# 2.   Connect wires to the connections between the Ammeter and Breadboard
# 3.   Connect the wires to various locations along the board and observe when the ammeter beeps or not

# %% [markdown]
# **Observations**
#
#
# 1.   The top section beeps when the wires are inside holes horizontal to each other
# 2.   The thinner sections (except for the top) beep when the wires are inside holes vertical to each other
# 3.   The wider sections beep when the wires are inside holes horizontal to each other
