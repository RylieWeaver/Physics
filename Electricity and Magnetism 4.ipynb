# %% [markdown]
# <a href="https://colab.research.google.com/github/RylieWeaver9/Physics/blob/main/Electricity%20and%20Magnetism%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

#Plot Through t=50 in intervals of 0.1
t=np.arange(0.1,50,0.1)

#Define Things
omega = 1
yB_E = -1/(2*omega)*sin(omega*t)*t
zB_E = -1/(2*omega)*sin(omega*t)+1/(2*omega)

#Plot
plt.figure()
plt.plot(yB_E, zB_E, 'r-')
plt.xlabel("yB/E")
plt.ylabel("zB/E")
plt.show()

#This did not show up as I wanted. 
#Probably something to do with my unitless formulas
